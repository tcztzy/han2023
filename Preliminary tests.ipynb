# %%
library(conflicted)
library(readxl)
library(gtools)
library(plm)
library(tidyverse)
library(modelsummary)
library(huxtable)
library(dplyr)
#library(bda)
library(writexl)
#library(Hmisc)
library(sjPlot)
library(DescTools)
library(caTools)
library(psych)
library(pcse)
conflict_prefer("lag", "stats")
conflict_prefer("Mean", "modelsummary")
conflict_prefer("N", "modelsummary")
conflict_prefer("SD", "modelsummary")
conflicted::conflicts_prefer(plm::lag)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# Learn more about sjPlot with 'browseVignettes("sjPlot")'.
#
# [conflicted] Will prefer stats::lag over any other package.
# [conflicted] Will prefer modelsummary::Mean over any other package.
# [conflicted] Will prefer modelsummary::N over any other package.
# [conflicted] Will prefer modelsummary::SD over any other package.
# [conflicted] Removing existing preference.
# [conflicted] Will prefer plm::lag over any other package.

# %%
df <- pdata.frame(read.csv(file.path(path.expand('~'), 'OneDrive/PhD Dissertation/Data_Code/Data/index_data_regvariables.csv')),
                  index=c("Numeric","Year"))
df["lnFDIstock_w"] <- as.vector(winsor(df["lnFDIstock"], trim = .01))
df_sum <- df %>% select('SDI','lnFDIstock_w','financial','urban','property','tax', 'war_intensity')
df_withoutsdi <- df %>% select('lnFDIstock_w','financial','urban','property','tax','war_intensity')

# %%
###统计性描述
datasummary(All(df_sum) ~ N + Min + Max + Mean + SD, data = df, fmt = 2,
            output = file.path(path.expand('~'), 'OneDrive/PhD Dissertation/Regression Results/summary.docx'))

# %%
#' correlation_matrix
#' Creates a publication-ready / formatted correlation matrix, using `Hmisc::rcorr` in the backend.
#'
#' @param df dataframe; containing numeric and/or logical columns to calculate correlations for
#' @param type character; specifies the type of correlations to compute; gets passed to `Hmisc::rcorr`; options are `"pearson"` or `"spearman"`; defaults to `"pearson"`
#' @param digits integer/double; number of decimals to show in the correlation matrix; gets passed to `formatC`; defaults to `3`
#' @param decimal.mark character; which decimal.mark to use; gets passed to `formatC`; defaults to `.`
#' @param use character; which part of the correlation matrix to display; options are `"all"`, `"upper"`, `"lower"`; defaults to `"all"`
#' @param show_significance boolean; whether to add `*` to represent the significance levels for the correlations; defaults to `TRUE`
#' @param replace_diagonal boolean; whether to replace the correlations on the diagonal; defaults to `FALSE`
#' @param replacement character; what to replace the diagonal and/or upper/lower triangles with; defaults to `""` (empty string)
#'
#' @return a correlation matrix
#' @export
#'
#' @examples
#' `correlation_matrix(iris)`
#' `correlation_matrix(mtcars)`
correlation_matrix <- function(df, 
                               type = "pearson",
                               digits = 3, 
                               decimal.mark = ".",
                               use = "all", 
                               show_significance = TRUE, 
                               replace_diagonal = FALSE, 
                               replacement = ""){
  
  # check arguments
  stopifnot({
    is.numeric(digits)
    digits >= 0
    use %in% c("all", "upper", "lower")
    is.logical(replace_diagonal)
    is.logical(show_significance)
    is.character(replacement)
  })
  # we need the Hmisc package for this
  require(Hmisc)
  
  # retain only numeric and boolean columns
  isNumericOrBoolean = vapply(df, function(x) is.numeric(x) | is.logical(x), logical(1))
  if (sum(!isNumericOrBoolean) > 0) {
    cat('Dropping non-numeric/-boolean column(s):', paste(names(isNumericOrBoolean)[!isNumericOrBoolean], collapse = ', '), '\n\n')
  }
  df = df[isNumericOrBoolean]
  
  # transform input data frame to matrix
  x <- as.matrix(df)
  
  # run correlation analysis using Hmisc package
  correlation_matrix <- Hmisc::rcorr(x, type = )
  R <- correlation_matrix$r # Matrix of correlation coeficients
  p <- correlation_matrix$P # Matrix of p-value 
  
  # transform correlations to specific character format
  Rformatted = formatC(R, format = 'f', digits = digits, decimal.mark = decimal.mark)
  
  # if there are any negative numbers, we want to put a space before the positives to align all
  if (sum(R < 0) > 0) {
    Rformatted = ifelse(R > 0, paste0(' ', Rformatted), Rformatted)
  }
  
  # add significance levels if desired
  if (show_significance) {
    # define notions for significance levels; spacing is important.
    stars <- ifelse(is.na(p), "   ", ifelse(p < .001, "***", ifelse(p < .01, "** ", ifelse(p < .05, "*  ", "   "))))
    Rformatted = paste0(Rformatted, stars)
  }
  # build a new matrix that includes the formatted correlations and their significance stars
  Rnew <- matrix(Rformatted, ncol = ncol(x))
  rownames(Rnew) <- colnames(x)
  colnames(Rnew) <- paste(colnames(x), "", sep =" ")
  
  # replace undesired values
  if (use == 'upper') {
    Rnew[lower.tri(Rnew, diag = replace_diagonal)] <- replacement
  } else if (use == 'lower') {
    Rnew[upper.tri(Rnew, diag = replace_diagonal)] <- replacement
  } else if (replace_diagonal) {
    diag(Rnew) <- replacement
  }
  
  return(Rnew)
}

#' save_correlation_matrix
#' Creates and save to file a fully formatted correlation matrix, using `correlation_matrix` and `Hmisc::rcorr` in the backend
#' @param df dataframe; passed to `correlation_matrix`
#' @param filename either a character string naming a file or a connection open for writing. "" indicates output to the console; passed to `write.csv`
#' @param ... any other arguments passed to `correlation_matrix`
#'
#' @return NULL
#'
#' @examples
#' `save_correlation_matrix(df = iris, filename = 'iris-correlation-matrix.csv')`
#' `save_correlation_matrix(df = mtcars, filename = 'mtcars-correlation-matrix.csv', digits = 3, use = 'lower')`
save_correlation_matrix = function(df, filename, ...) {
  write.csv2(correlation_matrix(df, ...), file = filename)
}

# %%
###相关性系数
library("Hmisc")
cor <- cor(df_withoutsdi, method = c("pearson"))

# library("GGally")
# library("tidyverse")
# df_withoutsdi %>% ggpairs
correlation_matrix(df_withoutsdi, type = "spearman", show_significance = TRUE, digits =2, use="lower")

df_withoutsdi %>% correlation_matrix(type="spearman", show_significance=TRUE, digits =2, use="lower") %>% as_hux() %>% quick_docx(file=file.path(path.expand('~'), 'OneDrive/PhD Dissertation/Regression Results/correlation.docx'))
# Out:
#               lnFDIstock_w  financial  urban    property  tax
# lnFDIstock_w   1.00
# financial      0.31***       1.00
# urban         -0.07         -0.38***    1.00
# property       0.08          0.33***   -0.11*    1.00
# tax           -0.38***      -0.03      -0.22***  0.18**    1.00
# war_intensity  0.25***      -0.13*      0.22*** -0.13*    -0.18***
#               war_intensity
# lnFDIstock_w
# financial
# urban
# property
# tax
# war_intensity  1.00

# %%
###方差膨胀因子
library(car)
reg.lm <- lm(SDI~lnFDIstock_w + financial + urban + property + tax + war_intensity, data = df)

vif(reg.lm)
vif_values <- vif(reg.lm)
mean(vif_values)

VIF_table<-hux(变量名 = names(vif_values), VIF = as.numeric(vif_values), VIF2 = 1/as.numeric(vif_values), add_colnames = TRUE)
quick_docx(VIF_table, file = path.expand("~/OneDrive/PhD Dissertation/Regression Results/VIFtable.docx"))
# Out:
# Loading required package: carData
#  lnFDIstock_w     financial         urban      property           tax
#      1.411540      1.439464      1.301959      1.184970      1.321898
# war_intensity
#      1.169791
# [1] 1.304937

# %%
####横截面依赖性检验
CD_test_results <- tibble(
  var_name = character(),
  z = numeric(),
  p.value = numeric(),
)
for (name in names(df_sum)) {
  if (name == "Numeric" || name == "Year" || name == "Region" || name == "incomegroup" || name == "Alpha.3.code" || name == "CountryName_CN") {
    next
  }
  result <- tryCatch({
    pcdtest(df_sum[[name]])
  }, warning = function(warning_condition) {
  }, error = function(error_condition) {
      print(paste("Error in", name))
  })
  CD_test_results <- CD_test_results %>% add_row(var_name = name, z = result$statistic[["z"]], p.value = result$p.value)
}


CD_test_results %>% as_hux() %>%
    set_number_format(2) %>%
    set_width(0.4) %>%
    quick_docx(file = path.expand("~/OneDrive/PhD Dissertation/Regression Results/cdtest.docx"))

# %%
###单位根检验
library(tseries)
###If p-value < 0.05 then no unit roots present.

###Augmented Dickey-Fuller Test
# lapply(df_sum, function(x) adf.test(x[!is.na(x)], 
#            alternative='stationary', k=1))

###Phillips-Perron
# lapply(df_sum, function(x) pp.test(x[!is.na(x)], 
#            alternative='stationary'))

###CIPS
# cipstest(df_sum$SDI, type = "none")

###kpss
# lapply(df_sum, function(x) kpss.test(x[!is.na(x)], 
#            "Level"))

###purtest concludes many tests, levinlin is one of them
purtest(df_sum, test = "levinlin", exo = "intercept", pmax=5)
tests_results <- tibble(
  var_name = character(),
  LLC = character(),
  CIPS = character(),
  ADF_Fisher = character(),
  PP_Fisher = character(),
  KPSS = character()
)
p.value.stars <- function (p) {
  if (p < 0.001) {
    return ("***")
  } else if (p < 0.01) {
    return ("**")
  } else if (p < 0.05) {
    return ("*")
  } else {
    return ("")
  }
}
for (name in names(df_sum)) {
  if (name == "Numeric" || name == "Year" || name == "Region" || name == "incomegroup" || name == "Alpha.3.code" || name == "CountryName_CN" || name == "war_intensity") {
    next
  }
  result <- purtest(df_sum[[name]], test = "levinlin", exo = "intercept", pmax=5)
  z <- result$statistic$statistic[['z']]
  p.value <- result$statistic$p.value[[1]]
  LLC <- paste(z, p.value.stars(p.value))
  result <- cipstest(df_sum[[name]], type = "none")
  z <- result$statistic[[1]]
  p.value <- result$p.value
  CIPS <- paste(z, p.value.stars(p.value))
  result <- adf.test(df_sum[[name]], alternative='stationary', k=1)
  z <- result$statistic[[1]]
  p.value <- result$p.value
  ADF_Fisher <- paste(z, p.value.stars(p.value))
  result <- pp.test(df_sum[[name]], alternative='stationary')
  z <- result$statistic[[1]]
  p.value <- result$p.value
  PP_Fisher <- paste(z, p.value.stars(p.value))
  result <- kpss.test(df_sum[[name]], "Level")
  z <- result$statistic[[1]]
  p.value <- result$p.value
  KPSS <- paste(z, p.value.stars(p.value))
  tests_results <- tests_results %>% add_row(var_name = name, LLC = LLC, CIPS = CIPS, ADF_Fisher = ADF_Fisher, PP_Fisher = PP_Fisher, KPSS = KPSS)
}
tests_results
# Out:
# 	Levin-Lin-Chu Unit-Root Test (ex. var.: Individual Intercepts)
#
# data:  df_sum
# z = -5.4574, p-value = 2.416e-08
# alternative hypothesis: stationarity
# Warning message in selectT(l, theTs):
# “the time series is short”
# Warning message in cipstest(df_sum[[name]], type = "none"):
# “p-value greater than printed p-value”
# Warning message in adf.test(df_sum[[name]], alternative = "stationary", k = 1):
# “p-value smaller than printed p-value”
# Warning message in pp.test(df_sum[[name]], alternative = "stationary"):
# “p-value smaller than printed p-value”
# Warning message in kpss.test(df_sum[[name]], "Level"):
# “p-value smaller than printed p-value”
# Warning message in selectT(l, theTs):
# “the time series is short”
# Warning message in cipstest(df_sum[[name]], type = "none"):
# “p-value greater than printed p-value”
# Warning message in adf.test(df_sum[[name]], alternative = "stationary", k = 1):
# “p-value smaller than printed p-value”
# Warning message in pp.test(df_sum[[name]], alternative = "stationary"):
# “p-value smaller than printed p-value”
# Warning message in kpss.test(df_sum[[name]], "Level"):
# “p-value greater than printed p-value”
# Warning message in selectT(l, theTs):
# “the time series is short”
# Warning message in adf.test(df_sum[[name]], alternative = "stationary", k = 1):
# “p-value smaller than printed p-value”
# Warning message in pp.test(df_sum[[name]], alternative = "stationary"):
# “p-value smaller than printed p-value”
# Warning message in kpss.test(df_sum[[name]], "Level"):
# “p-value greater than printed p-value”
# Warning message in selectT(l, theTs):
# “the time series is short”
# Warning message in cipstest(df_sum[[name]], type = "none"):
# “p-value greater than printed p-value”
# Warning message in kpss.test(df_sum[[name]], "Level"):
# “p-value greater than printed p-value”
# Warning message in selectT(l, theTs):
# “the time series is short”
# Warning message in cipstest(df_sum[[name]], type = "none"):
# “p-value smaller than printed p-value”
# Warning message in adf.test(df_sum[[name]], alternative = "stationary", k = 1):
# “p-value smaller than printed p-value”
# Warning message in pp.test(df_sum[[name]], alternative = "stationary"):
# “p-value smaller than printed p-value”
# Warning message in kpss.test(df_sum[[name]], "Level"):
# “p-value greater than printed p-value”
# Warning message in selectT(l, theTs):
# “the time series is short”
# Warning message in cipstest(df_sum[[name]], type = "none"):
# “p-value greater than printed p-value”
# Warning message in adf.test(df_sum[[name]], alternative = "stationary", k = 1):
# “p-value smaller than printed p-value”
# Warning message in pp.test(df_sum[[name]], alternative = "stationary"):
# “p-value smaller than printed p-value”
# Warning message in kpss.test(df_sum[[name]], "Level"):
# “p-value smaller than printed p-value”
#   var_name     LLC                   CIPS                ADF_Fisher
# 1 SDI          -2.84652718346144 **  -0.955618815746401  -4.4970348204141 *
# 2 lnFDIstock_w -9.40372380886515 *** -1.50457747086295   -4.66815175363104 *
# 3 financial    -4.47902711767813 *** -1.74841393565695 * -4.10130565598318 *
# 4 urban        3.88031535025202      -0.784579339655591  -3.52664752147851 *
# 5 property     -8.00612952794883 *** -1.91464681868227 * -4.3269194206098 *
# 6 tax          13.1350773521207      -1.42053192441821   -5.11444537997827 *
#   PP_Fisher           KPSS
# 1 -46.5733432892945 * 2.12184210935408 *
# 2 -43.3370367210953 * 0.131759659992849
# 3 -32.2609667838565 * 0.171151442838443
# 4 -23.4917633961703 * 0.261484868019208
# 5 -41.6620651183981 * 0.134821213598956
# 6 -52.8844809500145 * 0.812654644832893 *

# %%
###如果p值高于0.05，表明homoskedasticity，不存在异方差
library(lmtest)
bptest(SDI~lnFDIstock_w + financial + urban + property + tax + war_intensity, data = df, studentize=F)
# Out:
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
# 	Breusch-Pagan test
#
# data:  SDI ~ lnFDIstock_w + financial + urban + property + tax + war_intensity
# BP = 32.181, df = 6, p-value = 1.506e-05

# %%
###协整检验

# %%
summary(df$lnFDIstock_w)
# Out:
# total sum of squares: 873.6633
#        id      time
# 0.8045207 0.1373423
#
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   4.780   7.424   8.436   8.430   9.399  11.950

# %%
lm <- plm(SDI ~ lnFDIstock_w + I(lnFDIstock_w^2) + financial + urban + property + tax + war_intensity, data=df, model="within", effect = "twoways")
a <- lm$coefficients[["lnFDIstock_w"]]
b <- lm$coefficients[["I(lnFDIstock_w^2)"]]
breakpoint <- -a/(2*b)
df$lnFDIstock_lower <- ifelse(df$lnFDIstock_w < breakpoint, df$lnFDIstock_w, 0)
df$lnFDIstock_upper <- ifelse(df$lnFDIstock_w >= breakpoint, df$lnFDIstock_w, 0)
df$lnFDIstock_is_upper <- ifelse(df$lnFDIstock_w >= breakpoint, 1, 0)
glm(SDI ~ lnFDIstock_lower + lnFDIstock_upper + lnFDIstock_is_upper, family="poisson", data=df) %>% summary()
# Out:
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.470712”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.472522”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.479859”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.496331”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.510256”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.518066”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.522195”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.531574”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.531259”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.542569”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.538403”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.536336”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.542654”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.537347”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.534268”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.526083”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.481692”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.480943”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.484220”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.479380”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.480322”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.477173”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.484679”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.481885”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.496404”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.508730”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.502168”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.517337”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.518197”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.511475”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.525115”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.528299”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.442556”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.449327”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.460085”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.458473”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.466595”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.468282”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.469220”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.470426”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.481728”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.483567”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.481618”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.483969”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.484239”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.485197”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.487431”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.494865”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.450090”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.437714”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.435377”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.459927”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.463799”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.478044”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.469327”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.484335”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.483648”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.491302”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.471090”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.462337”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.467097”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.458972”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.456516”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.466340”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.439027”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.437242”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.432934”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.438981”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.439892”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.459908”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.464711”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.460287”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.457652”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.463655”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.464719”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.463506”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.467310”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.476941”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.476114”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.479614”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.491734”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.492986”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.496608”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.498650”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.500925”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.499702”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.500801”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.501377”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.505560”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.503138”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.502281”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.503365”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.510880”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.497569”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.495564”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.499493”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.490081”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.487005”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.489371”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.514415”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.516906”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.520726”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.506070”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.512504”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.514269”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.508707”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.509535”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.514611”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.522346”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.520590”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.529340”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.519139”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.450998”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.457069”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.456608”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.459501”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.457708”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.457975”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.459990”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.446034”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.452075”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.454925”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.453170”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.464603”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.465235”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.472879”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.468859”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.459605”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.538293”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.541462”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.542560”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.527284”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.545425”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.554470”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.547218”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.547791”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.549987”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.554539”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.548954”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.538100”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.540715”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.533287”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.541153”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.529158”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.464406”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.464858”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.473011”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.462024”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.464205”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.465920”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.462438”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.473699”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.474241”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.462694”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.455964”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.475690”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.468293”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.467978”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.459001”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.450452”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.509353”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.521809”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.519341”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.523601”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.536819”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.543568”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.543244”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.544266”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.540422”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.540594”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.540545”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.544926”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.543948”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.550894”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.562508”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.560154”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.473391”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.487063”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.478174”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.479817”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.491077”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.494516”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.496204”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.489845”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.491270”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.489703”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.490458”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.491704”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.498407”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.495142”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.496012”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.496646”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.513114”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.504300”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.507617”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.498590”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.498620”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.499400”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.490114”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.488587”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.496408”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.497995”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.495796”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.498194”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.510499”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.506710”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.506691”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.500206”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.518957”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.521767”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.522120”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.526284”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.523931”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.520589”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.522209”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.524313”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.529036”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.530556”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.529560”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.537953”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.532141”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.531695”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.530833”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.532664”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.555913”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.570819”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.564865”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.573819”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.570370”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.572322”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.573308”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.567157”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.569652”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.561153”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.558238”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.555225”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.535440”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.550026”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.547189”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.555508”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.518179”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.526245”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.528103”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.530768”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.539716”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.541275”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.535882”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.535941”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.537960”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.539401”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.541577”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.541502”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.546608”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.548055”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.545937”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.547757”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.497378”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.476244”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.484186”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.481580”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.497349”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.514767”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.512777”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.513407”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.506698”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.554799”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.552385”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.565886”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.557463”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.579126”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.579925”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.595959”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.452683”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.464444”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.454249”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.458934”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.491502”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.508662”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.514699”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.532763”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.523911”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.524742”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.518373”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.524465”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.510492”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.521940”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.522771”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.495866”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.576885”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.577106”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.577346”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.585112”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.596619”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.593223”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.603373”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.594662”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.591722”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.593630”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.601732”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.596805”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.596848”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.606899”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.587408”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.589103”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.563411”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.567711”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.566809”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.572353”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.568464”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.574808”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.569440”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.569881”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.563292”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.564811”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.559102”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.567983”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.566903”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.575609”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.576600”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.573033”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.468349”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.478465”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.473958”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.484033”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.501629”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.509991”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.500741”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.504663”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.498863”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.500189”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.500276”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.499760”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.494639”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.503033”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.495665”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 0.486938”
# Call:
# glm(formula = SDI ~ lnFDIstock_lower + lnFDIstock_upper + lnFDIstock_is_upper,
#     family = "poisson", data = df)
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -0.112491  -0.042601  -0.007873   0.040174   0.134132
#
# Coefficients: (2 not defined because of singularities)
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         -0.630487   0.405907  -1.553    0.120
# lnFDIstock_lower    -0.004872   0.047364  -0.103    0.918
# lnFDIstock_upper           NA         NA      NA       NA
# lnFDIstock_is_upper        NA         NA      NA       NA
#
# (Dispersion parameter for poisson family taken to be 1)
#
#     Null deviance: 1.0234  on 335  degrees of freedom
# Residual deviance: 1.0129  on 334  degrees of freedom
# AIC: Inf
#
# Number of Fisher Scoring iterations: 4
